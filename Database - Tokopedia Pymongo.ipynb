# %%
import pymongo

client = pymongo.MongoClient("mongodb+srv://tarangga:pymongo_123@cluster0.fwcgr.mongodb.net/online_shop_db?retryWrites=true&w=majority")
db = client.get_database('online_shop_db')

# %%
import shelve

shelf = shelve.open("filename.shlf") # the same filename that you used before, please
my_dict = shelf["my_dict"]
shelf.close()

# %%
db.tokopedia.insert_many(my_dict)

# %%
my_dict
# Out:
# [{'label': nan,
#   'Name': 'Liftable Foldable Phone Holder Stand HP meja Robot RT-US04',
#   'discount': '26%',
#   'real_price': 'Rp89.000',
#   'price': 'Rp66.000',
#   'location': 'Jakarta Barat',
#   'shop': nan,
#   'num_review': 37,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUE6A1N6A1d6_KDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthbm-7q3OBUsthosHFHpUdHAyObm-srcHi6seFHmFiy3zwrfo5rM1i6sHRHZdOos1pH_JfosepHpHfoZFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoq_ep_920H7Ok39PoqMoE_Ozs81N2Z9o-Q1dFyfFN8B29zSBgHMP2_fB-P7B2PfBxHByOgAUN8u2c692gHsBN3Bo-ojBke3BHe72OysUOqB2_Z_g-qj17_M2S8JOE1_-HuOgD3BP-PJNJ1MOo8_V2_jzg8jh1uMho8MWR3uPcqB2Iu_-qq1BpZ37N83V9gICiQAB03BxmgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Aom83Ua1sVgHO-MyuPzq1Y2Z9P-q9P2ysoGrVtaQIuyH7N5ysomgMV913Bvq1BRZ3BRq3oyuMhsQMhMgJPcQMoNZ_g-QAKa_MFdPOxEeMgozsBM_1ydPOxEeMgoe7BpZ3N6qMUpZMhyHj2Nysoj8B2_Z_g-qj7p_uH7H1Nku92ouJ1a_M2z8jOE__-617BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjjp_1H7HJOJu_u6uJ1a_1zg81YJ3_u-QsnYUiFiP9oBrBY2gmUEUsnibm-xQcri6i-sy9zBgfYa8uYi8uYFrMYjP3o7UiFiQSuWyMua9fYM9fVjraUEH_1DUMNOQ3-BrBYxgIowrMuhUsthoZFiyfV79fBjraUE3pyObAyfbAHFoszPbm-X9foxQMz2gcV7guYxgIHi6srObm-xyBY7g9o7Usti_iUDUSC5rRzwy3hSUstigcuMUiFiPMuarfB5QiUEUSyaUiFiyfhOrRzBrBY2gVYfHiUEoAnNoseDUSCaq3oB9f-2gmUEoAnFbm-SQfVD9fBjUstpwe?t=desktop&src=directory&r=https%3A%2F%2Fwww.tokopedia.com%2Fmavic-store%2Fliftable-foldable-phone-holder-stand-hp-meja-robot-rt-us04-merah-muda%3Fsrc%3Dtopads&page=1&ob=5&dv=desktop&management_type=1',
#   'information': {'product': 'Liftable Foldable Phone Holder Stand HP meja Robot RT-US04 - Merah Muda',
#    'num_sale': '126',
#    'Kondisi': 'Baru',
#    'Berat': '350 Gram',
#    'Kategori': 'Stand Handphone',
#    'Etalase': 'Holder Vivan Robot',
#    'num_review': '37',
#    'num_discuss': '6',
#    'desription': 'BARU DAN ORIGINAL 100%\nGARANSI 1 TAHUN RESMI ROBOT INDONESIA\n#DijaminOri #DijaminResmi #DijaminBergaransi\n\nSpesifikasi:\nBrand : Robot\nType : RT-US04\nMaterial : ABS+ aluminum alloy\nColor : White / Pink / Black\nRotation angle : 35°\nProduct net weight : 209g\nProduct size : 100mm x 100mm x 200mm\n\nPengenalan Produk :\n1. Phone Holder dengan ketinggian yang dapat di atur\n2. Membuat ada lebih nyaman\n3. Bisa di tarik sampai ketinggian 86mm\n4. Dapat di sesuaikan keatas dan kebawah 35° dan tidak akan longar walau ditarik 10.000 kali\n5. Alas lebih berat sehingga lebih stabil\n6. Design simple dan portable\n7. Alas full silikon terbaru yang membuat handphone dan tablet tidak mudah lecet\n8. Dapat mengisi daya sambil menonton\n9. Phone Holder yang tidak menghalagi subtitle\n10. Dapat digunakan pada handphone dan Tablet\n\nIn The Box:\n1 x Liftable ROBOT RT-US04 Foldable Aluminum Alloy Universal Phone Holder White\n1 x Tools\n1 x Kartu Garansi\nLihat Selengkapnya',
#    'store': 'MAVIC_STORE',
#    'stars': ['36', '1', '0', '0', '0']},
#   '_id': ObjectId('612db934129b7aaf751e4dd4')},
#  {'label': nan,
#   'Name': 'KABEL DATA ORIGINAL BASEUS USB IPHONE CABLE 2.4A LIGHTING FAST CHARGER',
#   'discount': '0%',
#   'real_price': 'Rp50.200',
#   'price': 'Rp50.200',
#   'location': 'Tangerang Selatan',
#   'shop': nan,
#   'num_review': 91,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEoAyNoAJfoseDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstabm-7q3OBUsthosHFHpUdHAyObm-srcHi6sjOHmFiy3zwrfo5rM1i6sHf6md76_1fo_1R6ArFHsURoaFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoe7BpZ3O6HcoD692qu7gN3_-Sq1Y2Z9P-q9P2y_-3o3ea69BqzsBE3_UN8u2_Z_g-qjV2_JoGP3Uao32q17jfZ32VoJNkgRxo8BJa_VP3QV29Z9z6zV-W_9jhq1NJ392HuVgD_920POB9zM2qzO1a3MB-r7BW69BxufzFyMFNqO2yeMgxuOV2_fB-P7B2PfBiH72F3s-DPuKpeSBiHBUh3_oZgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Ao6QfUpeMgxuOV2_fB-P7B2PfBs3VgDyfNDgMzIzMNs81jfZ3FdHjND6IPy8j-M_1yNgjOc6IPy8j-M_1o-r7BX_M2iH72D3A-G83UpgI2q17jfZ32oHjYAoACvuV1a_BzuH7YJyRPoqjjp_SB-r7BX_M2iH72D3Ao6QVByZM2xe7jfZ32-H7Y_oAuoqBja_1z-o1Ok39B6zJ77Z3dFvZUDUSupg9-wq3ei6iUFUiFiy3hSUstiyfV7g3P5rSBwySBwrI-5gIusPmUDUMNOQ3-BrBY5gBYxgIHi6sJObm-XP3Oig9-wy3zp9R-BrZUEH_1DUMoxPVY2gIHi6BDfoZFfoiFpHArh9ZFiQBYsy3Njq3zxPcuwy3zpUstRoZFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMzBgiUDUSgBrSo2Qfdi6i-fHiUDUMoDP9o7g9-wq3zwPsUi6se7osnpbm-FrMBsguYiq3ei6sjOHmFigfYxQVY2gmUEHR7?ob=5&src=directory&management_type=2&t=desktop&dv=desktop&page=1&r=https%3A%2F%2Fwww.tokopedia.com%2Fdenana%2Fkabel-data-original-baseus-usb-iphone-cable-2-4a-lighting-fast-charger%3Fsrc%3Dtopads',
#   'information': {'product': 'KABEL DATA ORIGINAL BASEUS USB IPHONE CABLE 2.4A LIGHTING FAST CHARGER',
#    'num_sale': '188',
#    'Kondisi': 'Baru',
#    'Berat': '80 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'BASEUS',
#    'num_review': '91',
#    'num_discuss': '8',
#    'desription': 'STOCK READY BARANG TERBATAS HARGA PROMO!!!\nBRAND NEW SEGEL dan SEMUA BARANG ASLI 100%\n\nproduk BASEUS yang kami jual DIJAMIN ORIGINAL, BILA TERBUKTI PALSU UANG AKAN KAMI KEMBALIKAN FULL 2X LIPAT + ONGKIR !\n\nKabel Data Baseus USB FOR IPHONE LIGHTING\nKevlar Cable 2.4A LIGHTING\n\nHARGA NORMAL = Rp 65.000\nHARGA PROMO = Rp 52.200\n\nREADY:\n- Hitam\nPanjang\n- 100 cm\nGaransi 6 Bulan\n\nFitur:\n- Panjang Kabel 100cm\n- Mendukung fAST CHARGING\n- Pengisian Cepat 2.4A\nTransmisi berkecepatan tinggi, kecepatan pengisian ekstrim, hemat waktu dan energi\n- Perlindungan penutup penuh SR\nDesain penutup penuh yang utuh, tahan terhadap pembengkokan, tidak retak, tidak patah\n- Kabel Kevlar dikepang dengan kerapatan tinggi\nKevlar dikepang dengan kerapatan tinggi, kuat dan fleksibel, tahan lama\n- Sabuk velcro\nDengan sabuk Velcro untuk kemudahan menyimpan dan dibawa\n- Tembaga & Timah Murni\nMengurangi daya tahan arus, mempercepat pengisian hingga 40%\n- Transmisi dengan kecepatan tinggi 480Mbps dapat menikmati video / hiburan lebih cepat dari yang lain\n\nTerimakasih telah mengunjungi DENANASTORE :)\nLihat Selengkapnya',
#    'store': 'denanastore',
#    'stars': ['88', '2', '0', '1', '0']},
#   '_id': ObjectId('612db934129b7aaf751e4dd5')},
#  {'label': nan,
#   'Name': 'PHONE STAND HP LIPAT UNIVERSAL BAHAN BESI FOLDABLE PHONE HOLDER BESI',
#   'discount': '0%',
#   'real_price': 'Rp9.900',
#   'price': 'Rp9.900',
#   'location': 'Jakarta Barat',
#   'shop': nan,
#   'num_review': 847,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEH_nfH_KFHArNbm-xgVY789CBUsthbm-FQRo2PcB5QiUEHaFiPcBWgZUEH_ypHAHa6AnfoZFiyRCsUstOHAnDUMVj9RosQR-BUstposKXHAUNoAJaHpn7H_jfoZFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBo1pzE_Ozu8jNJgpzo8MoN_1z08jOJZ_C-q9P23_oZ8uKp_Mhg3J2ky1o-ojBkz9PHqj7F_jzS81NEu_z6qjBR_M2So1NNZ9o-Q9zDguxjPMoW1MgsHjNfyfOuq1Y2Z9P-q9P2yM7NPujau3Bvq1Bd_7zgoJO1__C6q_VD3BP3q1h11_CqqjO7332zHjONHAVquJ7O_1PcqVja1Mh6QuB2_JoGPMoWQcNxupuM3jP3POKaQcW-qMY2_1o-r7BW69BxufzFyMFNPfoW63Wju7dF3A-Dq7BkQfBoe7BpZ37N83V9gICiQABEy1rNPOKaQcW-qMY2_1o-r7BXzsVq3JtO3AoZqVtp_3Bvq1B2_JoG8Bja69BqusB2yf7NHfHau3Bvq1BE_M2SP1OJZ_u6zJuN_92CHJO1qp-617BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjOd_jH78JNJ1926uJ1a_7zSP7O1yRB617tNUiFiP9oBrBY2gmUEUsnibm-xQcri6i-ig9o79RoBQchBriUDUMNOQ3-BrBY5gBYxgIHi6sJObm-XP3Oig9-wy3zp9R-BrZUEH_1DUMoxPVY2gIHi6BDfoZFfoiFpHAyh9ZFiQBYsy3Njq3zxPcuwy3zpUstRoZFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMzBgiUDUSgBrSo2Qfdi6i-fHiUDUMoDP9o7g9-wq3zwPsUi6sUdHp17bm-FrMBsguYiq3ei6s1FHmFigfYxQVY2gmUEHR7?r=https%3A%2F%2Fwww.tokopedia.com%2Flnacc%2Fphone-stand-hp-lipat-universal-bahan-besi-foldable-phone-holder-besi%3Fsrc%3Dtopads&src=directory&page=1&t=desktop&dv=desktop&ob=5&management_type=1',
#   'information': {'product': 'PHONE STAND HP LIPAT UNIVERSAL BAHAN BESI FOLDABLE PHONE HOLDER BESI',
#    'num_sale': '3.498',
#    'Kondisi': 'Baru',
#    'Berat': '200 Gram',
#    'Kategori': 'Holder Handphone',
#    'Etalase': 'Semua Etalase',
#    'num_review': '855',
#    'num_discuss': '24',
#    'desription': 'Phone Holder dengan ketinggian yang dapat diatur sehingga tidak membuat leher atau pundak lelah , tidak perludigengam sehingga lebih santai\n- dapat disesuaikan 35 derajat\n- bisa digunakan semua tipe smartphone & Table\n- dengan mudah mencabut dan memasang kabel bisa mengisi daya',
#    'store': 'LNA ACC',
#    'stars': ['715', '81', '33', '11', '15']},
#   '_id': ObjectId('612db934129b7aaf751e4dd6')},
#  {'label': nan,
#   'Name': 'INBEX 7.5Inch Phone Holder/Tablet Holder / Multi-Function Stander',
#   'discount': '68%',
#   'real_price': 'Rp279.000',
#   'price': 'Rp89.000',
#   'location': 'Kab. Bekasi',
#   'shop': nan,
#   'num_review': 1325,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEosHFH_rpHsHDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUst7bm-7q3OBUsthosHFHpUdHAyObm-srcHi6s1FHmFiy3zwrfo5rM1i6sHfoZdfHAjaHArN6_rhHsr7omFirpowQcYSUstig9BGqMzUZMggQj2fgAo6QJBkQfBoq_eO_S2C81Y1yRPoqMDp_1z-o1NEe92-q9P23_oZ8uKp_Mhg3J2ky1o-ojBke3BHe72a3BxDHfUpZMWyH7NkysoGQJBkQfBoe7BpZ37OPM-W_Mh-qMY2_uzSHjYJz926zVB73BP3QVB2HAC6zOBE_VP-HJNk_9z6uOuE_OzmqVB9_MWquV2WZ3BRq3UpZSCqHMhO3A-ZQcoc69Cqe7jfZ32Cq1hAZSgsQ3hXyurOgMoUZSgqZVgkgJyNrV2AZ_g-qjV2_JoGPMoWQcNxupuMyp-tPMoc69Cqe7jfZ32Cq1hAZSxjuOgNguyNHVB9gI2-qMY2Z3BRq3Ha_SgsQugM33NGPMep_Mh-qMY2_92gH1hk39PvuJBR_S20o1NEz9B68BJFZ3BRq3Ha_SgsQugMyp-3qcoW_MY-qMY2_32sP7hkyp-vzJJh_Ozgo1NE__u68MW2gBJYvZUDUSupg9-wq3ei6iUFUiFiy3hSUstiyMupPVYpg3hDg9Uibm-XP3Oig9-wQfgwy3zpUsthoZFiQSuWyMua9fVjrOYag9Ji6sJObm-sy9zwq3zpUs2Qos1DosyDHpnfHu7DUMNwyfVXgcBjy9zB9fVjraUEop1DUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-jg3yibm-fg9-pq3YXUstiPsUibm-sQIupPcua9fBj9RyaUstpH_raomFirI-2yfuwyMBjUstOHAnDUMP5y3hwq3ei6soY?page=1&t=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Finbexelectronic%2Finbex-7-5inch-phone-holder-tablet-holder-multi-function-stander%3Fsrc%3Dtopads&src=directory&ob=5&dv=desktop&management_type=1',
#   'information': {'product': 'INBEX 7.5Inch Phone Holder/Tablet Holder / Multi-Function Stander',
#    'num_sale': '2.070',
#    'Kondisi': 'Baru',
#    'Berat': '1.200 Gram',
#    'Kategori': 'Holder Handphone',
#    'Etalase': 'Desktop Dudukan',
#    'num_review': '1.327',
#    'num_discuss': '44',
#    'desription': '***Membeli produk ini sekarang akan memberi Anda remote Bluetooth sebagai hadiah\n\nINBEX 10.5 Inch Tablet Holder/Lazypod Hp/Multi-Function Cantilever Stander for 5.1-10.5inci telepon\n\n🌷Ikuti toko, jadilah penggemar pada toko kami dan kirimkan screen shot bahwa anda sudah mengikuti toko kami, Anda dapat mengajukan kupon toko dari penjual.\n\nFitur\nBahan Besi Berat super Kuat\nBraket desktop datar ponsel kantilever universal yang dapat disesuaikan\nPutar dan lipat dengan bebas\nMendukung smartphone dan tablet\n\nDudukan ponsel dapat diputar 360 derajat, dengan lengan gooseneck panjang yang fleksibel, mudah memilih sudut yang diinginkan , Nyaman dan fleksibel.\n\nDudukan ponsel ini menjaga jarak yang lebih baik dari mata Anda. Dan juga memperbaiki postur tubuh yang salah secara ergonomis saat melihat ponsel. Sangat baik untuk kesehatan.\n\nBantalan busa melindungi tablet Anda dari kerusakan di semua titik kontak dan mencegah tablet jatuh.\n\nBisa untuk di Ranjang\nbisa dilantai\nbisa di meja\nbisa untuk live streaming\n\nSangat membantu bagi teman2 yang video creator untuk :\n⭐ Video Memasak\n⭐ Video Unboxing\n⭐ Video Tutorial\n⭐ Video Menulis dan Melukis\n⭐ Video Crafting & Sclupting\n⭐ Video Kerajinan Tangan\ndan masih banyak lagi lainnya.\n\nSpesifikasi\n1.Bahan: Besi + plastik\n2.Ukuran Lipat: 16 * 16 * 30CM\n3.Berat produk: 1070G\n4.Berat maksimal: 60cm\n5.Cocok: smartphone / tablet 5.1-10.5 inci\n\nKelengkapan Paket\n☑ Klip Telepon / Tablet * 1\n☑ Dudukan Telepon * 1\n☑ Base holder * 1\n\n【FAQ】\n1.Apakah ada layanan garansi？\n💡Ya, Tokopedia INBEX Toko resmi menyediakan garansi 6 bulan untuk setiap item.\n2.Apakah produk ini tersedia?\n💡 Ya, ini ready stock, selamat datang untuk membeli.\n3.Berapa lama waktu pengiriman?\n💡Waktu pengiriman H+1, estimasi pengiriman 1-5 hari dan masih tergantung pada jarak yang ditempuh oleh kurir.\n4.Apakah barang ini asli?\n💡 Ya, semua barang kami adalah 100 barang asli.\nLihat Selengkapnya',
#    'store': 'INBEX Official Store',
#    'stars': ['1173', '105', '29', '9', '11']},
#   '_id': ObjectId('612db934129b7aaf751e4dd7')},
#  {'label': nan,
#   'Name': 'Cable Oppo VOOC Fast Charger Data Line-USB Cable Type-C',
#   'discount': '0%',
#   'real_price': 'Rp8.000',
#   'price': 'Rp8.000',
#   'location': 'Jakarta Pusat',
#   'shop': nan,
#   'num_review': 38,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEopK7oAHOo_JDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUstObm-7q3OBUsthosHFHpUdHAyObm-srcHi6syOHmFiy3zwrfo5rM1i6sHfomd7o_1RHsjpoAHR6_1Rbm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1OAZ9o-Q1dFyfFN8B29zSBgHMP2_fB-P7B2PfBxHByOgAUN8u2c692gHsBN3Bo-ojBke3BHe72OysUOqB2_Z_g-qj17_M2S8JOE1_-HuOgD3BP-PJNJ1MOo8_V2_jzg8jh1uMho8MWR3uPcqB2Iu_-qq1BpZ37N83V9gICiQAB03BxmgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Aom83Ua1sVgHO-MyuPzq1Y2Z9P-q9P2ysoGrVtaQIuyH7N5ysomgMV913Bvq1BRZ3BRq3oyuMhsQMhMgJPcQMoNZ_g-QAKa_MFdPOxEeMgozsBM_1ydPOxEeMgoe7BpZ3N6qMUpZMhyHj2Nysoj8B2_Z_g-qj7a_jH7HJN1u_ooqMWE_jzoH7Y1u_o-q9P2yp-6PMoWuMgsHBgtyfO6Q7BkQfBoqMHa_c2uH7OEgRx6qMHp_S2sHJYJZ3BM1_7YUiFiP9oBrBY2gmUEUsnibm-xQcri6i-sy9zBgfYa8uYi8uYFrMYjP3o7UiFiQSuWyMua9fYM9fVjraUEH_1DUMNOQ3-BrBYxgIowrMuhUsthoZFiyfV79fBjraUE3pyObAyfbAHFopVPbm-X9foxQMz2gcV7guYxgIHi6srObm-xyBY7g9o7Usti_iUDUSC5rRzwy3hSUstigcuMUiFiPMuarfB5QiUEUSyaUiFiyfhOrRzBrBY2gVYfHiUEoAefHAHDUSCaq3oB9f-2gmUEos1Fbm-SQfVD9fBjUstpwe?page=1&ob=5&t=desktop&dv=desktop&src=directory&r=https%3A%2F%2Fwww.tokopedia.com%2Fserbajualstore%2Fcable-oppo-vooc-fast-charger-data-line-usb-cable-type-c%3Fsrc%3Dtopads&management_type=2',
#   'information': {'product': 'Cable Oppo VOOC Fast Charger Data Line-USB Cable Type-C',
#    'num_sale': '356',
#    'Kondisi': 'Baru',
#    'Berat': '50 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Semua Etalase',
#    'num_review': '38',
#    'num_discuss': '2',
#    'desription': 'Spesifikasi:\n-Support : VOOC Fast Charger\n-Charging & DataOutput\n-Max. 4.0.A\n-Material PVC/100cm\n-Data Line USB Cable Type-C 7pin/1.0m\n\nFitur Produk:\n-Desain khusus,mencegah berliku dan menarik\n-Menggunakan konektor usb berkualitas tinggi,model internal untuk memperkuat,diperpanjang menggunakan waktu,desain bertahap,tidak perlu khawatir tentang shell telpon.\n-Pembuatan oleh bahan berkualitas tinggi,perlindungan lingkungan non-tonik\n-Freeling sangat baik,lipat setiap sudut dan sulit untuk simpul,tarik terus menurus\n\n-Charging dan Data\nKabel Data ini memungkinkan untuk mengisi dan sinkronisasi data dengan smartphone yang menggunakan koneksi USB. Kabel kompatibel untuk charger cepat dan data transfer data lebih cepat. Dengan kualitas material yang bagus menjadikan kabel data ini kuat dan tidak mudah rusak.\n\n-Kabel kualitas ini memungkinkan Anda untuk menghubungkan perangkat keras yang kompatibel dengan Type-C USB ke laptop atau desktop Anda, untuk mengisi daya telepon Anda dan bertukar sinkronisasi data secara bersamaan.\n-Kompatibel dengan pengisi daya listrik USB dan PC\n-Dengan koneksi USB standar, kabel ini kompatibel dengan pengisi daya utama yang menampilkan port USB, serta laptop atau PC - sehingga Anda memiliki fleksibilitas lengkap untuk kebutuhan pengisian daya Anda\n\nNB.\n-Sebelum klik beli !!!\n-Mohon Chating terlebih dulu untuk ketersediaan Stok yang Ready.\n-Jika memiliki pertanyaan, dapat di tanyakan langsung kepada kami melalui Chat produk pada halaman setiap produk.\n-Tidak Bergaransi=No retur=No Komplain\n-Original OEM(Original Equipment Manufacturer)Bkn dari vendor resmi OPPO\n\nWA: 082111998662\nLihat Selengkapnya',
#    'store': 'SERBA JUAL STORE',
#    'stars': ['37', '0', '0', '1', '0']},
#   '_id': ObjectId('612db934129b7aaf751e4dd8')},
#  {'label': 'Cashback',
#   'Name': 'ACMIC Braided Line Kabel Data Charger 100cm Fast Charging Cable',
#   'discount': '84%',
#   'real_price': 'Rp99.000',
#   'price': 'Rp15.900',
#   'location': 'Bandung',
#   'shop': nan,
#   'num_review': 9083,
#   'link': 'https://www.tokopedia.com/acmic/acmic-braided-line-kabel-data-charger-100cm-fast-charging-cable-iphone-gl100?whid=0',
#   'information': {'product': 'ACMIC Braided Line Kabel Data Charger 100cm Fast Charging Cable - iPhone GL100',
#    'num_sale': '22rb',
#    'Kondisi': 'Baru',
#    'Berat': '90 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Kabel Data Charger',
#    'num_review': '9.094',
#    'num_discuss': '260',
#    'desription': 'GARANSI 18 BULAN RUSAK GANTI BARU\nUNLIMITED CLAIM\nTANPA PERLU SIMPAN BOX\n\nSelama bisa klik BELI, berarti Stok Ready yah :)\n\nADA 6 VARIAN YANG KAMI JUAL :\n1. Micro USB GM100 = Kabel Micro USB untuk Android (Lihat produk di gambar Varian)\n2. Type-C USB GC100 = Kabel USB Type C untuk Android (Lihat produk di gambar Varian)\n3. iPhone GL100 = Kabel USB Lightning untuk iPhone (Lihat produk di gambar Varian)\n4. isi 2Pcs GM100 (Lebih Murah)\n5. isi 2Pcs GC100 (Lebih Murah)\n6. isi 2Pcs GL100 (Lebih Murah)\n\nINFO PENGIRIMAN & GARANSI\nKlik ➤ :\n\nCatatan:\nMohon videokan proses unboxing saat membuka paket demi mencegah hal-hal yang tidak diinginkan. Terima kasih :)\n\n▁▁▁▁▁▁▁▁▁\nInfo Produk:\n\nACMIC Braided Line Kabel Data Fast Charging\nPanjang : 1 meter\n\n✧ Terbuat dari nylon braided berkualitas tinggi.\n✧ Anti bending design, mencegah kerusakan pada ujung kabel hingga 6x lebih tahan lama.\n✧ Fast Charging (Mendukung Qualcomm Quick Charge 3.0) (untuk varian Micro USB dan Type-C )\n✧ Fast Charging hingga 2,4A (untuk varian iPhone Lightning)\n✧ Dapat digunakan sebagai kabel data (Speed up to 480Mbps)\n✧ Dengan fitur Smart Over Current Protection yang efektif mencegah kerusakan baterai ponsel.\n\n▁▁▁▁▁▁▁▁▁\n\nMau cari yang 2 meter atau 3 meter?\nKlik link di bawah ini yah :)\n\nLihat Selengkapnya',
#    'store': 'ACMIC Official Store',
#    'stars': ['8674', '332', '50', '10', '28']},
#   '_id': ObjectId('612db934129b7aaf751e4dd9')},
#  {'label': 'Cashback',
#   'Name': 'KABEL DATA TYPE-C BASEUS AUTOMATIC POWER-OFF FAST CHARGE 3A',
#   'discount': '55%',
#   'real_price': 'Rp198.000',
#   'price': 'Rp89.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 7849,
#   'link': 'https://www.tokopedia.com/baseus/kabel-data-type-c-baseus-automatic-power-off-fast-charge-3a-hitam-e1c9?whid=0',
#   'information': {'product': 'KABEL DATA TYPE-C BASEUS AUTOMATIC POWER-OFF FAST CHARGE 3A - Hitam',
#    'num_sale': '3.787',
#    'Kondisi': 'Baru',
#    'Berat': '71 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'KABEL DATA',
#    'num_review': '7.850',
#    'num_discuss': '1.054',
#    'desription': 'BS-CA-TCOFF-BK\n\nFitur:\n-Kabel Tipe-C Power-off Light-off\nUntuk perangkat elektronik dengan konektor Tipe-C yang mendukung transmisi data dan pengisian sekaligus.\n\n- Chip cerdas Power-off\nDirancang dengan chip cerdas yang secara otomatis berhenti mengisi daya saat baterai terisi penuh.\n\n-3.0A Quick Charge\nKabel Type-C pintar ini mengeluarkan daya output maksimum 3A untuk pengisian cepat\n\n- Lampu cerdas berbentuk C\nLampu berbentuk C menunjukkan status pengisian dalam tiga warna: merah (normal charging), biru(fast charging), dan hijau(full Charged)\n\nSpesifikasi:\nMerek: BASEUS\nModel: Baseus C-shaped Light Intelligent power-off Cable USB For Type-C 3A 1M\nBahan: Zinc Alloy + Polyester Woven Fabric\nOutput: 5V/3A Max\nKecepatan transmisi: 480Mbps\nCocok dengan: perangkat port Type-C\nWarna: Black\nFitur: 1 Pengisian daya akan otomatis berhenti dan lampu hijau akan padam 5 menit setelah baterai penuh.\n2. disarankan untuk mengunakan charger bawaan dari perangkat ponsel anda\n3. Fitur fast charging hanya berlaku ketika menggunakan kepala charger yang mendukung fast charging QC3.0\n\n\nBerat Paket: 71 gram\nDimensi Paket: 17.3*9*2.5 cm\n\nIsi Kemasan:\n1 x KABEL DATA TYPE-C BASEUS AUTOMATIC POWER-OFF FAST CHARGE 3A\n\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna——》garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['7315', '360', '91', '32', '52']},
#   '_id': ObjectId('612db934129b7aaf751e4dda')},
#  {'label': 'Cashback',
#   'Name': 'KEPALA CHARGER BASEUS 24W QUICK CHARGER QC3.0',
#   'discount': '37%',
#   'real_price': 'Rp125.000',
#   'price': 'Rp79.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 7212,
#   'link': 'https://www.tokopedia.com/baseus/kepala-charger-baseus-24w-quick-charger-qc3-0-putih?whid=0',
#   'information': {'product': 'KEPALA CHARGER BASEUS 24W QUICK CHARGER QC3.0 - Putih',
#    'num_sale': '15,2rb',
#    'Kondisi': 'Baru',
#    'Berat': '85 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'BASEUS X USAMS',
#    'num_review': '7.213',
#    'num_discuss': '599',
#    'desription': 'BS-CH-QC-WH\n\nPAKET HEMAT DAPAT KABEL DATA USAMS USB TO IPHONE\nhttps://www.tokopedia.com/usamsoffical/kabel-data-usams-u18-fast-charging-cable-2a-5v-iphone-micro-type-c-hitam-1m-iphone\n\nPAKET PB DAPAT POWERBANK USAMS 10.000MaH\n\n\nDeskripsi Produk\nMasih merasa ngecas pake wireless itu lamban?\nMungkin anda memakai charger yang tidak sesuai!\nSpesifikasi:\nMerek: Baseus\nModel: Baseus Wireless Charging Quick Charger (Qualcomm QC 3.0)\nBahan: PC + ABS\nInput: 100-240V - 50/60Hz 0.8a max\nOutput: 3.6V \'\'" 8V \'\'" 3.0A/12V \'\'" 2.0A\nWarna: Putih\nPanjang: 8.8*3.3*3.4 cm\nBerat Produk: 85 gram\nDimensi Paket: 11.3*3.7*3.8 cm\nIsi Paket:\n\nKEPALA CHARGER BASEUS 24W QUICK CHARGER QC3.0 *1\nWarranty Card*1\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna\'\'\'\'"\'\' garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['6702', '368', '87', '27', '29']},
#   '_id': ObjectId('612db934129b7aaf751e4ddb')},
#  {'label': 'Cashback',
#   'Name': 'KABEL DATA TYPE-C BASEUS CAFULE CABLE FOR TYPE-C 3A 1M',
#   'discount': '60%',
#   'real_price': 'Rp124.000',
#   'price': 'Rp49.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5980,
#   'link': 'https://www.tokopedia.com/baseus/kabel-data-type-c-baseus-cafule-cable-for-type-c-3a-1m-abu-abu?whid=0',
#   'information': {'product': 'KABEL DATA TYPE-C BASEUS CAFULE CABLE FOR TYPE-C 3A 1M - Abu-abu',
#    'num_sale': '13,5rb',
#    'Kondisi': 'Baru',
#    'Berat': '26 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'KABEL DATA',
#    'num_review': '5.984',
#    'num_discuss': '600',
#    'desription': 'BS-CA-TCCAF-GRY\nBS-CA-TCCAF-RD\n\n-Perlindungan yang kuat\nKabel dililit dengan kerapatan tinggi, tahan lama dan tahan aus.\n\n-3A Quick Charge\nKoneksi yang diperkuat dengan kabel yang lentur dan kuat . 3A Quick Charge, telepon Anda dapat terisi penuh lebih cepat daripada yang lain.\n\n-Kecepatan transmisi 480Mbps\n480Mbps transmisi data dengan kecepatan tinggi melalui kawat tembaga. Chip Smart IC memberikan perlindungan tegangan berlebih, Anda dapat mengisi daya perangkat Anda dengan aman.\n\n-Velcro\nDilengkapi dengan velcro untuk menjaga kabel Anda tetap rapi\n\nSpesifikasi:\nMerek: BASEUS\nBahan: Aluminium Alloy + TPE + kawat nilon\nOutput: 5V/3A Max\nKecepatan transmisi: 480Mbps\nCocok dengan: Huawei, Xiaomi, OPPO, VIVO, SAMSUNG, MEIZU atau perangkat port Type-C lainnya\nWarna: Grey-Black / Red-Black\n\nBerat Paket: 26 gram\nDimensi Paket: 17.3*11.8*0.2 cm\n\nIsi Kemasan:\n• 1 x KABEL DATA TYPE-C BASEUS CAFULE CABLE FOR TYPE-C 3A 1M\n• 1 x Velcro Belt\n\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna——》garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['5638', '264', '54', '13', '15']},
#   '_id': ObjectId('612db934129b7aaf751e4ddc')},
#  {'label': 'Cashback',
#   'Name': 'ACMIC CQC01 - Quick Charge 3.0 USB Wall Charger Fast Charging',
#   'discount': '74%',
#   'real_price': 'Rp299.000',
#   'price': 'Rp79.000',
#   'location': 'Bandung',
#   'shop': nan,
#   'num_review': 6209,
#   'link': 'https://www.tokopedia.com/acmic/acmic-cqc01-quick-charge-3-0-usb-wall-charger-fast-charging-cqc01-only?whid=0',
#   'information': {'product': 'ACMIC CQC01 - Quick Charge 3.0 USB Wall Charger Fast Charging - CQC01 Only',
#    'num_sale': '12,1rb',
#    'Kondisi': 'Baru',
#    'Berat': '90 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'ACMIC Adaptor',
#    'num_review': '6.213',
#    'num_discuss': '853',
#    'desription': 'GARANSI 18 BULAN RUSAK GANTI BARU\nUNLIMITED CLAIM\nTANPA PERLU SIMPAN BOX\n\n(Selama bisa klik BELI, berarti Stok Ready yah 😊)\n\nUntuk pembelian Grosir Klik :\nhttps://www.tokopedia.com/acmicgrosir\n\nINFO PENGIRIMAN & GARANSI :\n\n\nCatatan:\nMohon videokan proses unboxing saat membuka paket demi mencegah hal-hal yang tidak diinginkan. Terima kasih :)\n\n▁▁▁▁▁▁▁▁▁\nInfo Produk:\n\nACMIC CQC01 - QC3.0 Quick Charger\n⦿ Single USB Charger - Qualcomm Quick Charge 3.0\n⦿ 4x lebih cepat dibandingkan charger standar.\n⦿ ABS + PC CASE (Tangguh, tahan panas & api)\n⦿ Dengan Multiple Protection (Overcharge, Overcurrent, Overpower, Overheat, Overvoltage, Short Circuit)\n⦿ Dapat digunakan juga untuk Qualcomm Quick Charge 1.0 & 2.0\n⦿ Dapat menjadi charger standar untuk non-Quick Charge devices.\n\n▁▁▁▁▁▁▁▁▁\nSPESIFIKASI :\nProduct Type = QC3.0 Quick Charger\nModel Name = CQC01\nInput = 110-240V AC 50/60Hz 0.6A Max\nOutput USB QC3.0 = 5V/3A, 9V/2A, 12V/1.5A\nPort = Single USB\n▁▁▁▁▁▁▁▁▁\nIsi Dalam Kotak:\n☑ ACMIC CQC01 QC3.0 Quick Charger\nLihat Selengkapnya',
#    'store': 'ACMIC Official Store',
#    'stars': ['5786', '288', '78', '29', '32']},
#   '_id': ObjectId('612db934129b7aaf751e4ddd')},
#  {'label': 'Cashback',
#   'Name': 'Uneed Nylon Kabel Data Micro USB Fast Charging 2.1A - UCBM1',
#   'discount': '10%',
#   'real_price': 'Rp22.000',
#   'price': 'Rp19.800',
#   'location': 'Jakarta Pusat',
#   'shop': nan,
#   'num_review': 7392,
#   'link': 'https://www.tokopedia.com/uneed-indonesia/uneed-nylon-kabel-data-micro-usb-fast-charging-2-1a-ucbm1-merah?whid=0',
#   'information': {'product': 'Uneed Nylon Kabel Data Micro USB Fast Charging 2.1A - UCBM1 - Merah',
#    'num_sale': '2.146',
#    'Kondisi': 'Baru',
#    'Berat': '200 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Cable and Converter',
#    'num_review': '7.393',
#    'num_discuss': '1.784',
#    'desription': 'NOTE : Buyer diwajibkan menuliskan keterangan warna yang diinginkan pada saat proses order, jika tidak menuliskan maka akan dikirimkan warna secara random sesuai stock yang tersedia saat ini\n\nUNEED NYLON CABLE MICRO USB\nUNEED membuat kabel yang kuat dengan lapisan tambahan, sehingga tercipta kabel yang tangguh dengan transfer data yang cepat untuk smartphone atau tablet yang menggunakan micro USB\nNYLON FIBER WOVEN\nKabel yang dibalut dengan anyaman serat nilon, menjadikannya kuat dan tangguh.\nGOOD QUALITY\nDengan bahan tembaga inti serta berlapis timah, anti-oksidasi agar tidak berkarat, serta dapat melakukan pengisian daya dengan cepat hingga maksimal 2.1A, dan dapat digunakan juga untuk melakukan transfer data dengan cepat.\n\n\nHIGHLIGHT\nQuick charge\nFast transfer data\nStrong cable with woven fabric\nCompatible all Gadget with micro USB\nGood quality\nCable Length 1 meter\n\nGaransi resmi 12 bulan terhitung dari tanggal pembelian dengan ketentuan:\nWajib ada kartu garansi & invoice pembelian harus disertakan saat claim garansi ( jika salah satu dari Kartu Garansi / Nota pembelian hilang maka Garansi VOID )\nLihat Selengkapnya',
#    'store': 'Uneed Indonesia',
#    'stars': ['6612', '550', '127', '48', '56']},
#   '_id': ObjectId('612db934129b7aaf751e4dde')},
#  {'label': 'Cashback',
#   'Name': 'ACOME Phone Holder Tablet iPad iPhone Android Still Alluminium Alloy',
#   'discount': '46%',
#   'real_price': 'Rp109.900',
#   'price': 'Rp59.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 6358,
#   'link': 'https://www.tokopedia.com/acomeindone/acome-phone-holder-tablet-ipad-iphone-android-still-alluminium-alloy-silver?whid=0',
#   'information': {'product': 'ACOME Phone Holder Tablet iPad iPhone Android Still Alluminium Alloy - Silver',
#    'num_sale': '11,2rb',
#    'Kondisi': 'Baru',
#    'Berat': '200 Gram',
#    'Kategori': 'Holder Handphone',
#    'Etalase': 'Phone Holder',
#    'num_review': '6.358',
#    'num_discuss': '107',
#    'desription': 'Deskripsi:\n\n✅ All Alumunium Alloy Material\n- Tekstur halus dan premium\n\n✅ Dapat dilipat seukuran kartu\n- Mudah disimpan dan dibawa\n\n✅ Atas Bawah Dapat Dirotasi 270°\n- Dapat disesuaikan dengan kebutuhan posisi Anda saat melihat layer handphone\n- Menonton film jadi lebih nyaman\n\n✅ Kompatibel dengan Semua Smartphone\n- Cocok dan ssuai dengan semua ukuran dan jenis smartphone\n\n✅ Putar penahan bawah dan kencangkan\n- Menahan berbagai berat, ukuran, dan jenis smartphone lebih steady dan kokoh\n\n✅ 4 Anti-Slip Pad\n- 4 bantalan silicon agar tidak mudah tergeser\n\n✅ Bisa nge-charge sambal nonton\n- Charging lebih nyaman dengan charging hole\n\n✅ Tonton film sesuka hati\n- Bingkai didesain tidak menghalangi layar\n\nKetentuan Garansi:\n1. Garansi 1 Tahun Tukar Baru Untuk Produk Tidak Berlaku Jika:\nA. Tidak Ditemukan Adanya Kerusakan\nB. Kerusakan Disebabkan Oleh Faktor Luar/Di Luar Kuasa\nC. Kerusakan Akibat Dari Kesalahan Pemakaian (Terjatuh, Tergores, Ternoda, Pecah, Terkena Air, Dll.)\n2. Syarat Klaim:\nA. Unit Masih Dalam Masa Garansi Dan Sesuai Dengan Kebijakan Garansi Yang Telah Ditetapkan\nB. Kelengkapan Dari Unit Harus Disertai Secara Lengkap (Dus, Kabel Charger, Buku Manual, Kartu Garansi, Dll)\nC. Dilengkapi Dengan Nota Pembelian (Print Out History Pembelian) Dan Informasi Kerusakan Unit\n*Note: Hubungi Customer Service Kami Melalui Layanan Chat, Untuk Mengetahui Prosedur Klaim Retur Atau Garansi Lebih Lanjut.\nLihat Selengkapnya',
#    'store': 'Acome Indonesia',
#    'stars': ['5823', '406', '84', '18', '27']},
#   '_id': ObjectId('612db934129b7aaf751e4ddf')},
#  {'label': 'Cashback',
#   'Name': 'KEPALA CHARGER BASEUS FAST CHARGING QC3.0/4.0 DUAL USB / TYPE-C 30W 5A',
#   'discount': '60%',
#   'real_price': 'Rp399.000',
#   'price': 'Rp159.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5991,
#   'link': 'https://www.tokopedia.com/baseus/kepala-charger-baseus-fast-charging-qc3-0-4-0-dual-usb-type-c-30w-5a-usb-usb-hitam?whid=0',
#   'information': {'product': 'KEPALA CHARGER BASEUS FAST CHARGING QC3.0/4.0 DUAL USB / TYPE-C 30W 5A - USB USB HITAM',
#    'num_sale': '12,4rb',
#    'Kondisi': 'Baru',
#    'Berat': '150 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'Charger',
#    'num_review': '5.993',
#    'num_discuss': '844',
#    'desription': 'BS-CH-PPS30W-BK (usb + tc)\nBS-CH-PPS30WQ-BK (usb + usb)\n\nTERDAPAT 2 VARIAN YAITU USB + TYPE C atau USB + USB\nMOHON PERHATIKAN VARIAN SEBELUM MELAKUKAN PEMBAYARAN\n\n1. QC 4.0 hanya tersedia dalam tipe c untuk jenis Port c dan membutuhkan kabel QC 4.0 yang didukung, Port USB hanya mendukung QC 3.0.\n\n2. ketika pengisian dua perangkat, sama seperti charger normal.\n\nOutput\n--Type-C : DC 5V/3A 9V/3A 12V/2.5A 15V/2A 20V/1.5A (For PD3.0 & Quick Charge4.0)\n--USB 1: DC 4.5V/5A 5V/4.5A 9V/3A 12V/2.5A Max (For Quick Charge3.0/SCP/FCP/AFC)\n--USB 2: DC 4.5V/5A 5V/4.5A 9V/3A 12V/2.5A Max (For Quick Charge3.0/SCP/FCP/AFC)\n--Type-C+USB: 5V/5A Max (At The Same Time)\n--USB 1+USB 2: 5V/5A Max (At The Same Time)\n\n-Intput\nAC 100-240V 50-60Hz 0.7A Max\n\nBerat Paket: 150 gram\nDimensi Paket:13*8.1*3.4\n\nIsi Paket:\n1*KEPALA CHARGER\n1*Manual\n\nBarang-barang lainnya tidak termasuk\n\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna——》 garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['5619', '226', '83', '19', '46']},
#   '_id': ObjectId('612db934129b7aaf751e4de0')},
#  {'label': 'Cashback',
#   'Name': 'Vention Kabel Data Micro Usb 3A Fast Charging Quick Charge Android',
#   'discount': '0%',
#   'real_price': 'Rp18.000',
#   'price': 'Rp18.000',
#   'location': 'Jakarta Barat',
#   'shop': nan,
#   'num_review': 5214,
#   'link': 'https://www.tokopedia.com/sinshe-tekno/vention-kabel-data-micro-usb-3a-fast-charging-quick-charge-android-col-black-0-25m?whid=0',
#   'information': {'product': 'Vention Kabel Data Micro Usb 3A Fast Charging Quick Charge Android - COL Black, 0.25m',
#    'num_sale': '11,8rb',
#    'Kondisi': 'Baru',
#    'Berat': '70 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'WIB',
#    'num_review': '5.224',
#    'num_discuss': '207',
#    'desription': 'Terdapat 2 varian\n1. Tipe COL Black : Material PVC\n2. Tipe COA Grey : Material Nylon Braided\n\nPanjang Kabel Dapat Dipilih Di menu Varian, dan Dikirim sesuai varian yang dipilih\nPembelian Grosir Bisa hubungi pihak kami terlebih dahulu untuk keakurasian berat barang\n\nBrand: Vention\nName: Micro USB Cable\nModel: COL / COA\nColor: Black / Grey\nInterface: USB Type-A Male/USB Micro-B Male\nInterface Technics: Nickel-plated\nTransmission Speed: 480Mbps\nConductor: Tinned-copper\nShell: PVC / Aluminum Alloy\nShielding: PVC / Aluminum Foil\nJacket: TPE+PVC / TPE+Nylon Braided Jacket\nAWG: 0.25-1M：24+28AWG；1.5-2M：22+28AWG；3M：18+28AWG\nOD: 3.5mm\nLength: 0.25/0.5/1/1.5/2/3M\nPower Supply: 3A\nWarranty: 1 Year\nPacking: PE Bag\nLihat Selengkapnya',
#    'store': 'VENTION by SinsheTekno',
#    'stars': ['4939', '217', '45', '9', '14']},
#   '_id': ObjectId('612db934129b7aaf751e4de1')},
#  {'label': 'Cashback',
#   'Name': 'KABEL DATA IPHONE BASEUS AUTOMATIC POWER-OFF FAST CHARGING 2.4A',
#   'discount': '53%',
#   'real_price': 'Rp146.000',
#   'price': 'Rp69.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 6455,
#   'link': 'https://www.tokopedia.com/baseus/kabel-data-iphone-baseus-automatic-power-off-fast-charging-2-4a-hitam?whid=0',
#   'information': {'product': 'KABEL DATA IPHONE BASEUS AUTOMATIC POWER-OFF FAST CHARGING 2.4A - Hitam',
#    'num_sale': '4.479',
#    'Kondisi': 'Baru',
#    'Berat': '70 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'KABEL DATA',
#    'num_review': '6.458',
#    'num_discuss': '822',
#    'desription': 'MOHON TULIS KETERANGAN WARNA/SIZE/ TIPE HP YANG DIMINTA, SEBELUM CHECK OUT, JIKA TIDAK KAMI AKAN KIRIMKAN RANDOM SESUAI PERSEDIAAN BARANG YANG ADA, TANPA PEMBERITAHUAN TERLEBIH DAHULU, NO COMPLAIN!!!\n\nBS-CA-IPOFF-BK\nBS-CA-IPOFF-RD\n\n-Setelah handphone terisi penuh, kabel data berhenti mengisi secara otomatis, melindungi baterai\ntanpa merusak handphone Anda.\n-Output 2.4A, pengisian cepat dalam waktu singkat.\n-Kabel berkualitas, elastis, tahan lama dan tangguh\n-Koneksi yang diperkuat dan bebas dari kabel longgar\n- 480Mbps transmisi data kecepatan tinggi melalui kawat tembaga\n-Dukung sinkronisasi data dan pengisian daya\n-Dirancang dengan lampu indikator berbentuk C yang berkedip dalam status pengisian daya; dan\nmenyala secara normal saat baterai terisi penuh, kemudian otomatis mati setelah setengah jam\ndalam keadaan normal\n-Panjang kabel 1M sepenuhnya memenuhi kebutuhan harian Anda\nSpesifikasi:\nMerek: BASEUS\nModel: Baseus C-shaped Light Intelligent power-off Cable\nBahan: Zinc Alloy + Polyester Woven Fabric\nArus keluaran: 2.4A\nKecepatan transmisi: 480 Mbps\nPanjang: 1 M\nWarna: Biru, Ungu, Merah\nKompatibel untuk iPhone X / 8/8 Plus Untuk iPhone 7/7 Plus Untuk perangkat 8pin Lainnya\nBerat Paket: 70 gram\nDimensi Paket: 17.2*9*2.3 cm\nIsi Paket:\nKABEL DATA IPHONE BASEUS AUTOMATIC POWER-OFF FAST CHARGING 2.4A*1\nKARTU GARANSI *1\n\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna\'\'\'\'"\'\' garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['5915', '340', '106', '48', '49']},
#   '_id': ObjectId('612db934129b7aaf751e4de2')},
#  {'label': 'Cashback',
#   'Name': 'ACMIC Flexy Line Kabel Data Charger 100cm Fast Charging Cable',
#   'discount': '82%',
#   'real_price': 'Rp79.000',
#   'price': 'Rp13.900',
#   'location': 'Bandung',
#   'shop': nan,
#   'num_review': 5375,
#   'link': 'https://www.tokopedia.com/acmic/acmic-flexy-line-kabel-data-charger-100cm-fast-charging-cable-iphone-fl100?whid=0',
#   'information': {'product': 'ACMIC Flexy Line Kabel Data Charger 100cm Fast Charging Cable - iPhone FL100',
#    'num_sale': '9.247',
#    'Kondisi': 'Baru',
#    'Berat': '90 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Kabel Data Charger',
#    'num_review': '5.383',
#    'num_discuss': '272',
#    'desription': 'GARANSI 18 BULAN RUSAK GANTI BARU\nUNLIMITED CLAIM\nTANPA PERLU SIMPAN BOX\n\nSelama bisa klik BELI, berarti Stok Ready yah :)\n\nADA 6 VARIAN YANG KAMI JUAL :\n1 Micro USB FM100 = Kabel Micro USB untuk Android (Lihat produk di gambar Varian)\n2 Type-C USB FC100 = Kabel USB Type C untuk Android (Lihat produk di gambar Varian)\n3 iPhone FL100 = Kabel USB Lightning untuk iPhone (Lihat produk di gambar Varian)\n4 isi 2Pcs FM100 (Lebih Murah)\n5 isi 2Pcs FC100 (Lebih Murah)\n6 isi 2Pcs FL100 (Lebih Murah)\n\nUntuk pembelian Grosir Klik :\n\n\nINFO PENGIRIMAN :\n\nCatatan:\nMohon videokan proses unboxing saat membuka paket demi mencegah hal-hal yang tidak diinginkan. Terima kasih :)\n▁▁▁▁▁▁▁▁▁\nInfo Produk:\n\nACMIC Flexy Line Kabel Data Charger 100cm Fast Charging Cable\nPanjang : 100cm\n\n⦿ Flexible High Grade Synthetic Rubber\n⦿ 2A Fast Charging\n⦿ Compatible with Quick Charge 3.0 (untuk varian Micro USB FM100 dan Type-C FC100)\n⦿ High Speed Data Transmision\nup to 480Mbps rapid data transfer\n⦿ Smart Over Current Protection\nEffectively Protect Battery from Over Current\n\nGaransi 18 Bulan\n\nRusak Ganti Baru\nLihat Selengkapnya',
#    'store': 'ACMIC Official Store',
#    'stars': ['5030', '259', '66', '8', '20']},
#   '_id': ObjectId('612db934129b7aaf751e4de3')},
#  {'label': 'Cashback',
#   'Name': 'ROBOT Aluminium Alloy Stand for Smartphone / Tablet - RT-US04',
#   'discount': '50%',
#   'real_price': 'Rp150.000',
#   'price': 'Rp74.900',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5269,
#   'link': 'https://www.tokopedia.com/robotofficial/robot-aluminium-alloy-stand-for-smartphone-tablet-rt-us04-merah-muda?whid=0',
#   'information': {'product': 'ROBOT Aluminium Alloy Stand for Smartphone / Tablet - RT-US04 - Merah Muda',
#    'num_sale': '10,9rb',
#    'Kondisi': 'Baru',
#    'Berat': '500 Gram',
#    'Kategori': 'Mount Handphone',
#    'Etalase': 'Phone Holder',
#    'num_review': '5.269',
#    'num_discuss': '203',
#    'desription': '💎Keunggulan:\n1. Phone holder simple & portable\n2. Sudut pandang holder dapat diatur 35 derajat\n3. Tinggi maksimal holder 8.8cm\n4. Bagian bawah holder sangat stabil\n\n😊Silahkan Bertanya Ke Costumer Service Mengenai Produk^^\n\n📋Spesifikasi:\n*Material: ABS+ aluminum alloy\n*Color: white\n*Rotation angle: 35°\n*Product net weight: 209g\n*Product size: 100mm*100mm*200mm\n\n📌Kelengkapan\n1x Holder\n\n⏳Ketentuan garansi:\n1. Garansi tidak berlaku jika:\na.Tidak ditemukan adanya kerusakan\nb.Kerusakan disebabkan oleh faktor luar/di luar kuasa\nc.Kerusakan akibat dari kesalahan pemakaian (terjatuh, tergores, ternoda, pecah, terkena air, dll.)\n2. Syarat klaim:\na.Unit masih dalam masa garansi dan sesuai dengan kebijakan garansi yang telah ditetapkan\nb.Kelengkapan dari unit harus disertai secara lengkap (dus, kabel charger, buku manual, kartu garansi, dll)\nc.Dilengkapi dengan nota pembelian (print out history pembelian) dan informasi kerusakan unit\n*Note: Hubungi customer service kami melalui layanan chat, untuk mengetahui prosedur klaim Retur atau Garansi lebih lanjut.\nLihat Selengkapnya',
#    'store': 'ROBOT OFFICIAL SHOP',
#    'stars': ['4934', '248', '55', '13', '19']},
#   '_id': ObjectId('612db934129b7aaf751e4de4')},
#  {'label': 'Cashback',
#   'Name': 'BASEUS PHONE HOLDER STAND HOLDER DUDUKAN HANDPHONE/PAD/DESKTOP BRACKET',
#   'discount': '79%',
#   'real_price': 'Rp480.000',
#   'price': 'Rp99.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5785,
#   'link': 'https://www.tokopedia.com/baseus/baseus-phone-holder-stand-holder-dudukan-handphone-pad-desktop-bracket-hitam?whid=0',
#   'information': {'product': 'BASEUS PHONE HOLDER STAND HOLDER DUDUKAN HANDPHONE/PAD/DESKTOP BRACKET - Hitam',
#    'num_sale': '10,7rb',
#    'Kondisi': 'Baru',
#    'Berat': '300 Gram',
#    'Waktu Preorder': '30 Hari',
#    'Kategori': 'Holder Handphone',
#    'Etalase': 'Phone Holder',
#    'num_review': '5.786',
#    'num_discuss': '171',
#    'desription': 'BS-UV-WYA-BK\nBS-UV-WYA-SLV\n\nTerbuat dari paduan aluminium + silikon, tahan lama dan elegan.\nCocok digunakan untuk menonton video, membaca dan belajar, bermain game, membuat panggilan telepon video dan konferensi video.\nCocok menjadi aksesoris meja yang bagus untuk kantor dan rumah Anda.\nKompatibel dengan: Apple / Samsung / Huawei dll. Ponsel pintar atau tablet lainnya\n\nSpesifikasi:\nBrand : Baseus\nNama Produk : Baseus Literary Youth Desktop Bracket (Telescopic)\nBahan : Aluminium Alloy\nCocok untuk: Ponsel, Tablet, Pad (4.7-12.9inch)\nTambahan: dapat dirotasi hingga 35derajat.\nCocok dengan:\niPhone XS Max / 11/11 Pro\nSamsung Galaxy S20/S20 Plus\nHuawei Mate 30 / Mate 30 Pro\nPonsel cerdas atau tablet lainnya\n\nBerat Paket: 300 gram\nDimensi Paket: 22*10.8*10.3cm\n\nIsi Paket:\n1* Baseus Phone Holder Stand Holder Dudukan Handphone/Pad/Desktop Bracket\n\nBarang-barang lainnya tidak termasuk\nTIDAK ADA GARANSI\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['5264', '368', '99', '25', '30']},
#   '_id': ObjectId('612db934129b7aaf751e4de5')},
#  {'label': 'Cashback',
#   'Name': 'ACMIC KeyLine Kabel Data Charger 20cm Fast Charging Lanyard Cable',
#   'discount': '61%',
#   'real_price': 'Rp99.000',
#   'price': 'Rp39.000',
#   'location': 'Bandung',
#   'shop': nan,
#   'num_review': 4807,
#   'link': 'https://www.tokopedia.com/acmic/acmic-keyline-kabel-data-charger-20cm-fast-charging-lanyard-cable-type-c-kcc20?whid=0',
#   'information': {'product': 'ACMIC KeyLine Kabel Data Charger 20cm Fast Charging Lanyard Cable - Type-C KCC20',
#    'num_sale': '2.221',
#    'Kondisi': 'Baru',
#    'Berat': '50 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Kabel Data Charger',
#    'num_review': '4.809',
#    'num_discuss': '544',
#    'desription': 'GARANSI 18 BULAN RUSAK GANTI BARU\nUNLIMITED CLAIM\nTANPA PERLU SIMPAN BOX\n\nSelama bisa klik BELI, berarti Stok Ready yah :)\n\nADA 3 VARIAN YANG KAMI JUAL :\n• Micro USB KMC20 = Kabel Micro USB untuk Android (Lihat produk di gambar Varian)\n• Type-C USB KCC20 = Kabel USB Type C untuk Android (Lihat produk di gambar Varian)\n• iPhone KiC20 = Kabel USB Lightning untuk iPhone (Lihat produk di gambar Varian)\n\nUntuk pembelian Grosir Klik :\n\n\nINFO PENGIRIMAN & GARANSI\nKlik ➤ :\n\nCatatan:\nMohon videokan proses unboxing saat membuka paket demi mencegah hal-hal yang tidak diinginkan. Terima kasih :)\n▁▁▁▁▁▁▁▁▁\nInfo Produk:\n\nACMIC KeyLine Kabel Data Charger 20cm Fast Charging Lanyard Cable\nPanjang : 20cm\n\n✧ Dilengkapi kabel klip\n✧ Dilengkapi tutup USB\n✧ Fast Charging\n✧ Mendukung Qualcomm Quick Charge 3.0 (untuk varian Micro USB KMC20 dan Type-C KCC20)\n✧ Terbuat dari bahan premium berkualitas tinggi.\n✧ Dapat digunakan sebagai kabel data (Speed up to 480Mbps)\n✧ Dengan fitur Smart Power Management yang efektif mencegah kerusakan baterai ponsel.\nLihat Selengkapnya',
#    'store': 'ACMIC Official Store',
#    'stars': ['4547', '200', '33', '12', '17']},
#   '_id': ObjectId('612db934129b7aaf751e4de6')},
#  {'label': 'Cashback',
#   'Name': 'KABEL DATA BASEUS PRIMARY COLORS 3IN1 MICRO+LIGHTNING+TYPE-C 3.5A 1.2M',
#   'discount': '36%',
#   'real_price': 'Rp124.000',
#   'price': 'Rp79.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5257,
#   'link': 'https://www.tokopedia.com/baseus/kabel-data-baseus-primary-colors-3in1-micro-lightning-type-c-3-5a-1-2m-hitam?whid=0',
#   'information': {'product': 'KABEL DATA BASEUS PRIMARY COLORS 3IN1 MICRO+LIGHTNING+TYPE-C 3.5A 1.2M - Hitam',
#    'num_sale': '13,3rb',
#    'Kondisi': 'Baru',
#    'Berat': '80 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'KABEL DATA',
#    'num_review': '5.260',
#    'num_discuss': '207',
#    'desription': 'BS-CA-3IN1PC-BK\n\nHANYA KABEL LIGHTNING SUPORT TRANSMISI DATA\n\nNOTE:TIDAK MENDUKUNG FAST CHARGING\n\nFitur utama:\nDesain tiga antarmuka\nAnda dapat mengisi tiga perangkat secara bersamaan.\n3,5A\nMendukung pengisian 3,5A, ia memiliki kinerja pengisian daya yang kuat.\nTiga warna untuk membedakan\nGunakan hitam, merah dan biru untuk membedakan antara 8 Pin, Type-C dan Micro USB interface.\nLebih mudah untuk mengidentifikasi kabel saat Anda menggunakannya.\nAnti-breaking dan anti-lilitan\nTerbuat dari poliamida berkualitas tinggi, kabel mudah ditekuk dan tahan lama.\nPanjang kabel 1.2 M\nCukup untuk memenuhi kebutuhan Anda.\nKompatibilitas yang luas\nSangat cocok untuk perangkat dengan 8 Pin, Micro USB atau Type-C interface.\n\nSpesifikasi:\nMerek: BASEUS\nModel: Baseus Three Primary Colors 3-in-1 Cable\nBahan: Aluminium Alloy + Nylon\nArus keluaran: 3.5A Max\nKecepatan transmisi: 480 Mbps\nPanjang: 1.2 M\nWarna: Hitam\nKompatibel untuk iPhone X / 8/8 Plus Untuk iPhone 7/7 Plus Untuk perangkat 8pin Lainnya\nOppo, VIVO, Power Banks, Samsung, Huawei, MI, Meizu\nBerat Paket: 80 gram\nDimensi Paket: 20.3*9.1*2cm\nIsi Paket:\nBASEUS PRIMARY COLORS 3 IN 1 MICRO USB +LIGHTNING+TYPE-C 3.5A 1.2 M *1\nKARTU GARANSI *1\n\nGaransi: 6 Bulan (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna\'\'\'\'"\'\'garansi void)\n\nLihat Selengkapnya',
#    'store': 'Baseus Official Store',
#    'stars': ['4856', '282', '73', '27', '22']},
#   '_id': ObjectId('612db934129b7aaf751e4de7')},
#  {'label': 'Cashback',
#   'Name': 'ACOME Kabel Data/Charger Type-C 100cm Fast Charging 3A - ASC010',
#   'discount': '50%',
#   'real_price': 'Rp90.000',
#   'price': 'Rp45.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 5575,
#   'link': 'https://www.tokopedia.com/acomeindone/acome-kabel-data-charger-type-c-100cm-fast-charging-3a-asc010-type-c-2m?whid=0',
#   'information': {'product': 'ACOME Kabel Data/Charger Type-C 100cm Fast Charging 3A - ASC010 - Type-C 2m',
#    'num_sale': '12,5rb',
#    'Kondisi': 'Baru',
#    'Berat': '100 Gram',
#    'Kategori': 'Kabel Data',
#    'Etalase': 'Cable Type-C Fast Charging',
#    'num_review': '5.578',
#    'num_discuss': '227',
#    'desription': '✅Hadir dengan konsep kabel rajut perpaduan dua warna\n\n✅Dilengkapi strap untuk memudahkan penyimpanan\n\n✅Arus maksimal 3A\n\n✅Dapat digunakan sebagai kabel charge atau kabel data\n\n✅Kompatibel dengan berbagai perangkat yang sudah menggunakan antarmuka Type-C\n\n✅Acome Intelligent Charge (AiC) adalah Teknologi Terbaru yang mampu mendukung seluruh jenis teknologi fast charging Quick Charge 3.0 (QC 3.0) , Power Delivery (PD) dan VOOC yang terdapat pada ponsel :\n- Samsung\n- iPhone\n- Oppo\n- Xiaomi\n- Redmi\n- Vivo\n\n✅AiC telah TERUJI dan mampu mengisi daya ponsel 3X lebih cepat\n\n✅FAST CHARGING, HARGA MIRING\n\nKetentuan Garansi:\n1. Garansi 1 Tahun Tukar Baru Untuk Produk Tidak Berlaku Jika:\nA. Tidak Ditemukan Adanya Kerusakan\nB. Kerusakan Disebabkan Oleh Faktor Luar/Di Luar Kuasa\nC. Kerusakan Akibat Dari Kesalahan Pemakaian (Terjatuh, Tergores, Ternoda, Pecah, Terkena Air, Dll.)\n2. Syarat Klaim:\nA. Unit Masih Dalam Masa Garansi Dan Sesuai Dengan Kebijakan Garansi Yang Telah Ditetapkan\nB. Kelengkapan Dari Unit Harus Disertai Secara Lengkap (Dus, Kabel Charger, Buku Manual, Kartu Garansi, Dll)\nC. Dilengkapi Dengan Nota Pembelian (Print Out History Pembelian) Dan Informasi Kerusakan Unit\n*Note: Hubungi Customer Service Kami Melalui Layanan Chat, Untuk Mengetahui Prosedur Klaim Retur Atau Garansi Lebih Lanjut.\nLihat Selengkapnya',
#    'store': 'Acome Indonesia',
#    'stars': ['5083', '331', '86', '24', '54']},
#   '_id': ObjectId('612db934129b7aaf751e4de8')},
#  {'label': 'Cashback',
#   'Name': 'KEPALA CHARGER TYPE C PD BASEUS QUICK CHARGER 20W IPHONE 12',
#   'discount': '61%',
#   'real_price': 'Rp330.000',
#   'price': 'Rp129.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 4409,
#   'link': 'https://www.tokopedia.com/baseus/kepala-charger-type-c-pd-baseus-quick-charger-20w-iphone-12-hitam?whid=0',
#   'information': {'product': 'KEPALA CHARGER TYPE C PD BASEUS QUICK CHARGER 20W IPHONE 12 - Hitam',
#    'num_sale': '7.818',
#    'Kondisi': 'Baru',
#    'Berat': '150 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'iP12 ACC',
#    'num_review': '4.409',
#    'num_discuss': '242',
# ...
#   'Name': 'ACOME Charger Single USB QC3.0 18W Fast Charging Garansi 12 Bulan AC01',
#   'discount': '37%',
#   'real_price': 'Rp79.000',
#   'price': 'Rp49.900',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 2426,
#   'link': 'https://www.tokopedia.com/acomeindone/acome-charger-single-usb-qc3-0-18w-fast-charging-garansi-12-bulan-ac01?whid=0',
#   'information': {'product': 'ACOME Charger Single USB QC3.0 18W Fast Charging Garansi 12 Bulan AC01',
#    'num_sale': '4.343',
#    'Kondisi': 'Baru',
#    'Berat': '250 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'Charger Car Charger Fast Charging',
#    'num_review': '2.426',
#    'num_discuss': '168',
#    'desription': 'Keunggulan :\n\n✅Single USB Output\n\n✅Fast Charging QC 3.0\n\n✅Garansi Resmi 12 Bulan Tukar Baru\n\n✅Arus maksimal 3A\n\n✅Kompatibel dengan berbagai brand smartphone\n\n✅Dimensi mungil, mudah dibawa dan disimpan\n\n✅Acome Intelligent Charge (AiC) adalah Teknologi Terbaru yang mampu mendukung seluruh jenis teknologi fast charging Quick Charge 3.0 (QC 3.0) , Power Delivery (PD) dan VOOC yang terdapat pada ponsel :\n- Samsung\n- iPhone\n- Oppo\n- Xiaomi\n- Redmi\n- Vivo\n\n✅AiC telah TERUJI dan mampu mengisi daya ponsel 3X lebih cepat\n\n✅FAST CHARGING, HARGA MIRING\n\nJadwal pengiriman :\nPesanan yang masuk sebelum jam 11:00 siang, akan dikirim pada hari yang sama. Selanjutnya, pesanan yang masuk di atas jam 11:00 siang, maka akan dikirim H+1\n\nKetentuan Garansi:\n1. Garansi 1 Tahun Tukar Baru Untuk Produk Tidak Berlaku Jika:\nA. Tidak Ditemukan Adanya Kerusakan\nB. Kerusakan Disebabkan Oleh Faktor Luar/Di Luar Kuasa\nC. Kerusakan Akibat Dari Kesalahan Pemakaian (Terjatuh, Tergores, Ternoda, Pecah, Terkena Air, Dll.)\n2. Syarat Klaim:\nA. Unit Masih Dalam Masa Garansi Dan Sesuai Dengan Kebijakan Garansi Yang Telah Ditetapkan\nB. Kelengkapan Dari Unit Harus Disertai Secara Lengkap (Dus, Kabel Charger, Buku Manual, Kartu Garansi, Dll)\nC. Dilengkapi Dengan Nota Pembelian (Print Out History Pembelian) Dan Informasi Kerusakan Unit\n*Note: Hubungi Customer Service Kami Melalui Layanan Chat, Untuk Mengetahui Prosedur Klaim Retur Atau Garansi Lebih Lanjut.\nLihat Selengkapnya',
#    'store': 'Acome Indonesia',
#    'stars': ['2175', '165', '46', '18', '22']},
#   '_id': ObjectId('612db934129b7aaf751e4e64')},
#  {'label': nan,
#   'Name': 'CASAN Charger Oppo A83 ORIGINAL 100% 5V-2A Micro USB [ASLI] Indonesia',
#   'discount': '0%',
#   'real_price': 'Rp64.000',
#   'price': 'Rp64.000',
#   'location': 'Jakarta Pusat',
#   'shop': nan,
#   'num_review': 47,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEHsrOosy7oseDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthHZFiPcBWgZUEH_ypHAHpoAyNHZFiyRCsUstaHAnFbm-xgVYpyfYagZUEHprRbsjaH_KaHs1doAj7H_yObm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1OAZ9o-Q1dFyfFN8B29zSBgHMP2_fB-P7B2PfBxHByOgAUN8u2c692gHsBN3Bo-ojBke3BHe72OysUOqB2_Z_g-Q1jF332qQVBW_MWHuVBd_M20PJNI3_C68_n7_3O6q1h1__z68jgk_BzDQJOIz9Bg17BpZ37N83V9gICiQAB03BxmgMV913Bvq1BRZ3BRq3UpZSCqHMhO3Aom83Ua1sVgHO-MyuPzq1Y2Z9P-q9P2ysoGrVtaQIuyH7N5ysomgMV913Bvq1BRZ3BRq3oyuMhsQMhMgJPcQMoNZ_g-QAKa_MFdPOxEeMgozsBM_1ydPOxEeMgoe7BpZ3N6qMUpZMhyHj2Nysoj8B2_Z_g-qj7p_Sj7o1Okz_zoqjjh_7zzo1NJz_-617BpZ3N6qMUpZMhyH7ND3uxGqMVAZ_g-qjOR_Mj7o1OJgpVvucHF_S2g8JYJqp--QsnYUiFiP9oBrBY2gmUEUsnibm-xQcri6i-sy9zBgfYa8uYi8uYFrMYjP3o7UiFiQSuWyMua9fYM9fVjraUEH_1DUMNOQ3-BrBYxgIowrMuhUsthoZFiyfV79fBjraUE3pyObAyfbArF9ZFiQBYsy3Njq3zxPcuwy3zpUstRomFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMzBgiUDUSgBrSo2Qfdi6i-fHiUDUMoDP9o7g9-wq3zwPsUi6seOH_URbm-FrMBsguYiq3ei6sUFHAnDUMP5y3hwq3ei6soY?src=directory&page=2&t=desktop&dv=desktop&ob=5&management_type=2&r=https%3A%2F%2Fwww.tokopedia.com%2Fpusataccoriginal%2Fcasan-charger-oppo-a83-original-100-5v-2a-micro-usb-asli-indonesia%3Fsrc%3Dtopads',
#   'information': {'product': 'CASAN Charger Oppo A83 ORIGINAL 100% 5V-2A Micro USB [ASLI] Indonesia',
#    'num_sale': '86',
#    'Kondisi': 'Baru',
#    'Berat': '150 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'CHARGER ORIGINAL 100%',
#    'num_review': '47',
#    'num_discuss': '5',
#    'desription': 'HATI2 BEREDAR BARANG OC ATAU OEM DENGAN BENTUK YG SAMA TAPI BEDA KUALITAS DENGAN HARGA YG TIDAK REALISTIS JAMINAN UANG KEMBALI JIKA TIDAK TERBUKTI ORIGINAL 100% OPPO\n\nGunakan selalu charger original untuk mencharging gadget kesayangan kamu, dengan\nmenggunakan charger original pengisian lebih cepat dan aman, jika kamu pengguna\nhp Oppo, Produk ini sangat cocok untuk pengganti charger kamu yg rusak.\n\nResiko menggunakan charger palsu / kw, pengisian terasa lambat, touchscreen\nterkadang suka eror ketika di sentuh saat di cas karena arus charger yg tidak\nstabil, selain ada resiko dapat merusak gadget, biasanya charger palsu juga\ntidak tahan lama, alias cepet rusak.\n\nSpecification :\n- Model : AK933GB\n- Input : AC 100-240V-50/60Hz\n- Output : DC 5V : 2A\n- Pengisian Cepat\n- Garansi 1 Minggu\n\nCHARGER INI BAWAAN OPPO A83 RESMI INDONESIA\n\nSupport untuk semua produk oppo yg menggunakan konektor micro USB.\n\nNB: BARANG SEPERTI GAMBAR KARENA REAL HASIL FOTO SENDIRI\n\nHARGA DAPAT BERUBAH SEWAKTU - WAKTU...!!\n\nTerima kasih dan selamat belanja\nLihat Selengkapnya',
#    'store': 'PUSAT ACC ORIGINAL',
#    'stars': ['42', '3', '2', '0', '0']},
#   '_id': ObjectId('612db934129b7aaf751e4e65')},
#  {'label': nan,
#   'Name': 'Stand Holder HP Handphone Penyangga Broadcasting Putar 360 Desktop',
#   'discount': '0%',
#   'real_price': 'Rp14.500',
#   'price': 'Rp14.500',
#   'location': 'Jakarta Pusat',
#   'shop': nan,
#   'num_review': 265,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEosydosKRopyDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthHiFiPcBWgZUEH_ypHAHpoAyNHZFiyRCsUstOHAnDUMVj9RosQR-BUstpoprXoAja6AURosUNoArNbm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1O2oAoo8MDp_32gP7OkyR2vucoN_MB-r7BW_sCsQABE3BPc8ujagfBvq1BRZ3BRq3JausujHsBN3jyN8Bja69Bq17jfZ32Cq1hAZSuiHsuk3Bo-ojBWZ_CgqB2D33O6q7h139x6qMW7_jPgHJNNHAzoQ1N2_VzooJNEzM26uchD_1PV8uB_Z9o-Q_BNyuPjrc-D63Wq3J-MyuPzq1Y2Z9P-q9P2ysoGrVtaQIuyH7-Nys-ZHujp1MgxuOV2_fB-P7B2PfBiH72F3s-DPuKp_MYiH7-MyuPzq1Y2Z9P-q9P2yOx3QcoXQcgjz7gXyRB-ojBD6A-6QAxR3I2mgjOc63gozsxR3I2mgjOAZ9o-QjNkysoGQVKaZSBiHfzE3Bo-ojBk__o68_eF_Oz-oJOkyp-oqMDF_S20q1hAZS2gHsBN3ByN8B29zSBgHMP2_fB-81NEe9u6zcoN_7zo81NJ__VvuVjO_joG6ZUDUSupg9-wq3ei6iUFUiFiy3hSUstiyfV7g3P5rSBwySBwrI-5gIusPmUDUMNOQ3-BrBY5gBYxgIHi6sJObm-XP3Oig9-wy3zp9R-BrZUEH_1DUMoxPVY2gIHi6BDfoZFfoiFpHAy79ZFiQBYsy3Njq3zxPcuwy3zpUstRomFiy3-wPcupPmUEUjdibm-FQRo79fVDgaUEUMzBgiUDUSgBrSo2Qfdi6i-fHiUDUMoDP9o7g9-wq3zwPsUi6se76_n7bm-FrMBsguYiq3ei6s1FHmFigfYxQVY2gmUEHR7?page=2&r=https%3A%2F%2Fwww.tokopedia.com%2Frajaob%2Fstand-holder-hp-handphone-penyangga-broadcasting-putar-360-desktop%3Fsrc%3Dtopads&ob=5&dv=desktop&management_type=1&t=desktop&src=directory',
#   'information': {'product': 'Stand Holder HP Handphone Penyangga Broadcasting Putar 360 Desktop',
#    'num_sale': '1.716',
#    'Kondisi': 'Baru',
#    'Berat': '350 Gram',
#    'Kategori': 'Stand Handphone',
#    'Etalase': 'Assosoris handphone',
#    'num_review': '266',
#    'num_discuss': '3',
#    'desription': "Deskripsi :\n\nMaterial Plastik Abs Kokoh dan Kuat\nBisa digunakan untuk HP max 7 inch\nBerputar 360 derajat\nTinggi dapat disesuaikan 30-45cm\n1 kg muat 4 pcs\n\nFeatures:\n\nMade of high-quality material, durable, firm, and stable to use.\nEasy to attach your device, convenient and simple to use and operate.\nFoldable arm stands,you can adjust the angle you need to find the best viewing\nangle.\nWeighted base, it's more stable, it's enough to support your phones or tablets.\nThe stands are removable,easy to collect and carry.\nConvenient to throw in your bag or backpack and perfect for taking family\ntravelling photos or videos.\nLihat Selengkapnya",
#    'store': 'Raja OB',
#    'stars': ['235', '22', '8', '0', '1']},
#   '_id': ObjectId('612db934129b7aaf751e4e66')},
#  {'label': nan,
#   'Name': 'Kotak Penyimpanan Kabel Data / Charger / Earphone Portable Multifungsi',
#   'discount': '0%',
#   'real_price': 'Rp9.000',
#   'price': 'Rp9.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 24,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEH_Jhosja6A1Rbm-xgVY789CBUsthbm-FQRo2PcB5QiUEH_HDUSz2Q31i6sJfHpnpHpef6_JDUMoFyaUEo_nFbm-xgVYpyfYagZUEHprfbsyaoAHFHpjaHpUao_1Rbm-pHOYDQfri6i-B812kgJxGgBBXZSgjH7NDZ325q1O_oI2o8jOE_92o8jOE_92o8jOE_92oH1B2PfBgHO-N3Ao6QVByZM2xe7jfZ32uq1hAZS-q3cFpysoGqOKp_M2iH72DZ325q1OAZ9o-Q_ufyMO6QJBkQfBgqB-2_MO3quja19z6qj1a_OHFHV2k1_oHucPN3_--PJOEgpoou77h_OPuPOB1ZMx-q9P2ysoGrVtaQIuyHB-Dy7yNrV2AZ_g-qjV2_JoGPMoWQcNxupuMy7xGPB2UuM2jzsBF3jo-ojBke3BHe72fyfODQMV9o3gsHMxfy7yNrV2AZ_g-qjV2_JoG8cz9uSBBusjF3uPj8jBkQfBy8Bja3I2mgjOc6IPyH_xR3I2mgjOc6IP-q9P2yp-6PMoWuMggQj2fgAo6QJBkQfBo8MHa_c2g81NJ_9Po8MWN_92-81N1u_o-q9P2yp-6PMoWuMgsHBgtyfO6Q7BkQfBoqMD7_c2SH1YJyp-ozJ7O_M2sH7O1gfBM1_7YUiFiP9oBrBY2gmUEUsnibm-xQcri6i-sy9zBgfYa8uYi8uYFrMYjP3o7UiFiQSuWyMua9fYM9fVjraUEH_1DUMNOQ3-BrBYxgIowrMuhUsthoZFiyfV79fBjraUE3pyObAyfbAepo_VPbm-X9foxQMz2gcV7guYxgIHi6sr7bm-xyBY7g9o7Usti_iUDUSC5rRzwy3hSUstigcuMUiFiPMuarfB5QiUEUSyaUiFiyfhOrRzBrBY2gVYfHiUEHsKFosnDUSCaq3oB9f-2gmUEo_nFbm-SQfVD9fBjUstpwe?page=2&t=desktop&dv=desktop&src=directory&ob=5&management_type=1&r=https%3A%2F%2Fwww.tokopedia.com%2Fecommerce%2Fkotak-penyimpanan-kabel-data-charger-earphone-portable-multifungsi-pink-tanpa-bubble%3Fsrc%3Dtopads',
#   'information': {'product': 'Kotak Penyimpanan Kabel Data / Charger / Earphone Portable Multifungsi - Pink, Tanpa Bubble',
#    'num_sale': '246',
#    'Kondisi': 'Baru',
#    'Berat': '30 Gram',
#    'Kategori': 'Pelindung Kabel',
#    'Etalase': 'Semua Etalase',
#    'num_review': '25',
#    'num_discuss': '0',
#    'desription': 'Package Included:\n1* storage box\nColour:\nPink\nWhite\nGreen\n\nSpecifications:\nName: Travel portable data cable storage box, multi-function rotatable earphone charging cable storage box\nColor: as shown\nMaterial: ABS\nSize: 10*10*2(cm)\nWeight: 29g\n\nDescription:\nTravel portable data cable storage box, multifunctional rotatable earphone charging cable storage box\nOptimal material, rest assured to use\nEffective storage, essential for home\nMultifunctional and versatile\nA variety of styles for you to choose\n\nnote:\n1.Please allow 0-1cm errors due to manual measurement.\n2.Item color displayed in photos may be showing slightly different on your computer monitor since monitors are not calibrated same.\n3.If you have any questions about the product, please contact us, we will patiently answer for you!\nLihat Selengkapnya',
#    'store': 'SmartChoice Shop',
#    'stars': ['24', '1', '0', '0', '0']},
#   '_id': ObjectId('612db934129b7aaf751e4e67')},
#  {'label': nan,
#   'Name': 'Holder HP Dashboard Mobil Universal Jepit 360 Car Phone Mount',
#   'discount': '0%',
#   'real_price': 'Rp55.000',
#   'price': 'Rp55.000',
#   'location': 'Jakarta Utara',
#   'shop': nan,
#   'num_review': 1262,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEoAUOHpraHsHDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthomFiPcBWgZUEH_ypHAHpoAyNHZFiyRCsUstpHAnDUMVj9RosQR-BUstpopyXosnNHpjN6AnRosra6AeDUSHp9fh5gaUEUMuNZM2jZJ2M33NGPMep_Mh-qMY2_3j7H1Oku9B6uJjh_32u81N1Z_VoqBu2_JoGqMzUZMgsHBgtyfO6Q7BkQfB6epzR_7zVHjOEZ_-6uJOR_M2V81Oku3BHe72a3BxDHfUpZMWyH7NkysoGQJBkQfBoe7BpZ37OPM-W_Mh-qMY2332Zq1NWuMBgHBV7_M2VHjY_HACqqBJp_VzS8ujaZ9zo8Mrp_uPoH1Y9u9PguJ2tZ3BRq3UpZSCqHMhO3A-ZQcoc69Cqe7jfZ32Cq1hAZSgsQ3hXyurOgMoUZSgqZVgkgJyNrV2AZ_g-qjV2_JoGPMoWQcNxupuMyp-tPMoc69Cqe7jfZ32Cq1hAZSxjuOgNguyNHVB9gI2-qMY23I2gHBxEeMgozsxR3AJdPOxEeMgozsxRZ3BRq3Ha_SgsQugM33NGPMep_Mh-qMY2_92sHjhk39PvuJ7O_OzSP7NE3_ooqMrFZ3BRq3Ha_SgsQugMyp-3qcoW_MY-qMY2_32sH1hku9B6qBBN_M2S8JOkgR2vuVB2gBJYvZUDUSupg9-wq3ei6iUFUiFiy3hSUstiyfV7g3P5rSBwySBwrI-5gIusPmUDUMNOQ3-BrBY5gBYxgIHi6sJObm-XP3Oig9-wy3zp9R-BrZUEH_1DUMoxPVY2gIHi6BDfoZFfoiFRHO7DUMNwyfVXgcBjy9zB9fVjraUEopeDUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-jg3yibm-fg9-pq3YXUstiPsUibm-sQIupPcua9fBj9RyaUst7o_H7HmFirI-2yfuwyMBjUstpHAnDUMP5y3hwq3ei6soY?page=2&ob=5&t=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Ftb-mutiarajaya%2Fholder-hp-dashboard-mobil-universal-jepit-360-car-phone-mount%3Fsrc%3Dtopads&dv=desktop&src=directory&management_type=1',
#   'information': {'product': 'Holder HP Dashboard Mobil Universal Jepit 360 Car Phone Mount',
#    'num_sale': '2.537',
#    'Kondisi': 'Baru',
#    'Berat': '200 Gram',
#    'Kategori': 'Mount Handphone',
#    'Etalase': 'Perlengkapan Mobil Motor',
#    'num_review': '1.262',
#    'num_discuss': '244',
#    'desription': 'Untuk Model lainnya klik link dibawah:\nhttps://www.tokopedia.com/tb-mutiarajaya/holder-hp-dashboard-mobil-universal-jepit-car-phone-mount\n\nHP bisa di putar vertikal / 360\n\n100% Brand New High Quality\nBoth stylish and practical\nHUD design does not obscure driver\'s view, safer driving.\nFixed and stable base, smart design\nCurved base design fasten to most car dashboard\nWith non-slip silicone does not scratch your car and phone\nOne hand operation easy to install, no tools required.\nSuitable for: mobile phone / smart phone / PDA / MP4 devices which 3"-6.8"\nLihat Selengkapnya',
#    'store': 'TB.Mutiara Jaya',
#    'stars': ['1082', '114', '46', '12', '8']},
#   '_id': ObjectId('612db934129b7aaf751e4e68')},
#  {'label': nan,
#   'Name': 'Adapter Fast Charger Kepala 4 Port USB 36W Quick Charge QC 3.0 Plug EU',
#   'discount': '0%',
#   'real_price': 'Rp52.000',
#   'price': 'Rp52.000',
#   'location': 'Jakarta Selatan',
#   'shop': nan,
#   'num_review': 534,
#   'link': 'https://ta.tokopedia.com/promo/v1/clicks/8a-xgVY2gmUEo_edosrRosHDUMVj9RzNrc1i6sJDUSC5rfB7q3YXUsthoZFiPcBWgZUEH_ypHAHpoAyNHZFiyRCsUstOHAnDUMVj9RosQR-BUstpopyXoAyOHAepHpefoAr7o_eDUSHp9fh5gaUEUMuNZM2jZJ2M33NGPMep_Mh-qMY2_jH78JNk3_-6qBja_M2gHjNk3_-6qBB2_JoGqMzUZMgsHBgtyfO6Q7BkQfBoe7BpZ3O7QcuygIgsQu-Myp-6PMoWu3Bvq1BRZ3BRq3-W69ugHBu2_fBGq1NIZ_-qu72k3jHFHjO13_uHuV-W_jzsPJYJZM2gq_CE_7zs8VBEu_uquJ-t_3OVq1hAZSgsQ3hXyurOgB2IuSPyHMh0Z325q1OAZ9o-Q_BNyuPjrc-D69PsQ_B0gVP6HVKaQcW-qMY2_1o-r7BW69BxufzFyMFN8MVI69PyHMh0Z325q1OAZ9o-Qjyh3BxGouKp1MxqH7O2_fBGgjNk3MgozsxR3I2mgBxEeMgozsxR3I2Cq1hAZS2gHsBN3ByNq3oW6_osHBu2_fB-8jNE39u6zVjh_1zz8jOE1_-6zcHF_Bzzq1hAZS2gHsBN3ByN8B29zSBgHMP2_fB-81YJ19uoqMWE_S2uH7YJ__o6qMPd_3BG6ZUDUSupg9-wq3ei6iUFUiFiy3hSUstiyfV7g3P5rSBwySBwrI-5gIusPmUDUMNOQ3-BrBY5gBYxgIHi6sJObm-XP3Oig9-wy3zp9R-BrZUEH_1DUMoxPVY2gIHi6BDfoZFfoiFRHV7DUMNwyfVXgcBjy9zB9fVjraUEopeDUMVi9RzBrRei6i-6UiFircYpPVYxQcri6i-jg3yibm-fg9-pq3YXUstiPsUibm-sQIupPcua9fBj9RyaUsthHs1R6ZFirI-2yfuwyMBjUstOHAnDUMP5y3hwq3ei6soY?ob=5&dv=desktop&r=https%3A%2F%2Fwww.tokopedia.com%2Fdodoe-1%2Fadapter-fast-charger-kepala-4-port-usb-36w-quick-charge-qc-3-0-plug-eu-hitam%3Fsrc%3Dtopads&t=desktop&src=directory&page=2&management_type=2',
#   'information': {'product': 'Adapter Fast Charger Kepala 4 Port USB 36W Quick Charge QC 3.0 Plug EU - Hitam',
#    'num_sale': '1.081',
#    'Kondisi': 'Baru',
#    'Berat': '100 Gram',
#    'Kategori': 'Charger Handphone',
#    'Etalase': 'HOBI DAN ELEKTRONIK',
#    'num_review': '534',
#    'num_discuss': '32',
#    'desription': 'PILIH WARNA YANG SESUAI DI SISTEM DAN PESANAN, KAMI TIDAK MENERIMA REQUEST WARNA LEWAT CATATAN/ CHAT, Untuk memilih varian warna yang berbeda,cukup pilih varian warna yg dinginkan lalu masukan ke keranjang, kemudian pilih varian warna kedua yg dinginkan masukan ke keranjang, lalu bayar bersamaan. JIKA MASIH MENINGGALKAN CATATAN, MAKA AKAN KAMI PROSES WARNA YANG SAMA SESUAI DENGAN PESANAN MASUK PADA SISTEM!\n\nDeskripsi Produk\n\nSpesifikasi:\nBrand: YOOGOO\nAndroid Type-c\nOutput power: 36W\nWorking efficiency: 85%\nVoltage adjustment rate: 5%\nWorking temperature: 0-50 ℃\nOutput ripple & noise: ≤100mVp-p\nOutput protection: short circuit protection, overvoltage protection, overcharge protection, overheating protection\nStorage temperature: -20 ℃ + 80 ℃\nApplicable products: smart phones, tablet computers, digital electronics, etc.\n\nIsi Paket:\n1*Yoogoo Charger\nBarang-barang lainnya tidak termasuk\n\nGaransi: No warranty (Cacat pabrik, langsung ganti baru. kerusakan akibat pengguna——》 garansi void)\n\n============PERHATIAN!!============\nJIKA ADA KELUHAN HARAP HUBUNGI CS!\nLihat Selengkapnya',
#    'store': 'DoDo_Elec',
#    'stars': []},
#   '_id': ObjectId('612db934129b7aaf751e4e69')}]
